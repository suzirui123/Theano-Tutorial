# %%
import numpy as np
import theano.tensor as T
import cPickle
import gzip
import os
import sys
import time
import theano

# %%
class LogisticRegression(object):
    def __init__(self, input, n_in, n_out):
        self.W = theano.shared(value = np.zeros((n_in, n_out), dtype = theano.config.floatX), name = 'W', borrow = True)
        self.b = theano.shared(value = np.zeros((n_out,), dtype = theano.config.floatX), name = 'b', borrow = True)
        self.p_y_given_x = T.nnet.softmax(T.dot(input, self.W) + self.b)
        self.y_pred = np.argmax(self.p_y_given_x, axis=1)
        self.params = [self.W, self.b]
        
    def negative_log_likelihood(self, y):
        return -T.mean(T.log(self.p_y_given_x)[T.arange(y.shape[0]), y])
    
    def errors(self, y):
        if y.ndim != self.y_pred.ndim:
            raise TypeError('y should have the same shape as self.y_pred', (y, y.type, 'y_pred', self.y_pred.type))
        if y.dtype.startswith('int'):
            return T.mean(T.neq(self.y_pred, y))
        else:
            raise NotImplementedError()
            
def load_data(dataset):
    data_dir, data_file = os.path.split(dataset)
    if data_dir == " " and os.path.isfile(dataset):
        new_path = os.path.join(os.path.split(__file__)[0], "..", "data", dataset)
        if os.path.isfile(new_path) or data_file == 'mnist.pkl.gz':
            dataset = new_path
    if (not os.path.isfile(dataset)) and data_file == 'mnist.pkl.gz':
        import urllib
        origin = ('http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz')
        print 'Downloading data from %s' % origin
        urllib.urlretrieve(origin, dataset)
    print '...loading data'
    f = gzip.open(dataset, 'rb')
    train_set, valid_set, test_set = cPickle.load(f)
    f.close()
        
    def shared_dataset(data_xy, borrow = True):
        data_x, data_y = data_xy
        shared_x = theano.shared(np.asarray(data_x, dtype=theano.config.floatX), borrow = True)
        shared_y = theano.shared(np.asarray(data_y, dtype=theano.config.floatX), borrow = True)
        return shared_x, T.cast(shared_y, 'int32')
        
    test_set_x, test_set_y = shared_dataset(test_set)
    train_set_x, train_set_y = shared_dataset(train_set)
    valid_set_x, valid_set_y = shared_dataset(valid_set)
        
    rval = [(train_set_x, train_set_y), (test_set_x, test_set_y), (valid_set_x, valid_set_y)]
    return rval
    
def sgd_optimization_mnist(learning_rate = 0.13, n_epochs =1000, dataset = 'mnist.pkl.gz', batch_size = 600):
    datasets = load_data(dataset)
    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]
        
    n_train_batches = train_set_x.get_value(borrow = True).shape[0] / batch_size
    n_valid_batches = valid_set_x.get_value(borrow = True).shape[0] / batch_size
    n_test_batches = test_set_x.get_value(borrow = True).shape[0] / batch_size     
    
    print '... building the model'
    index = T.lscalar()
    x = T.matrix('x')
    y = T.ivector('y')
    classfier = LogisticRegression(input = x, n_in = 28 * 28, n_out = 10)
    cost = classfier.negative_log_likelihood(y)
        
    test_model = theano.function(inputs = [index], outputs = classfier.errors(y), givens = {x: test_set_x[index * batch_size : (index + 1) * batch_size], y: test_set_y[index * batch_size : (index + 1) * batch_size]})
    validation_model = theano.function(inputs = [index], outputs = classfier.errors(y), givens = {x: valid_set_x[index * batch_size : (index + 1) * batch_size], y: valid_set_y[index * batch_size : (index + 1) * batch_size]})
        
    g_W = T.grad(cost=cost, wrt = classfier.W)
    g_b = T.grad(cost=cost, wrt=classfier.b)
        
    updates = [(classfier.W, classfier.W - learning_rate * g_W), (classfier.b , classfier.b - learning_rate * g_b)]
    
    train_model = theano.function(inputs = [index], outputs = cost, updates=updates, givens = {x: train_set_x[index * batch_size : (index + 1) * batch_size], y: train_set_y[index * batch_size : (index + 1) * batch_size]})
        
    print '... training the model'
    patience = 5000
    patience_increase = 2
    improvement_threshold = 0.995
    validation_frequency = min(n_train_batches, patience / 2)
    best_validation_loss = np.inf
    test_score = 0.
    tic = time.clock()
        
    done_looping = False
    epoch = 0
    
    while (epoch < n_epochs) and (not done_looping):
        epoch += 1
        for minibatch_index in xrange(n_train_batches):
            minibatch_avg_cost = train_model(minibatch_index)
            iter = (epoch - 1) * n_train_batches + minibatch_index
            if (iter + 1) % validation_frequency == 0:
                validation_losses = [validation_model(i) for i in xrange(n_valid_batches)]
                this_validation_loss = np.mean(validation_losses)
                print ('epoch %i, minibatch %i/%i, validation error %f %%' % (epoch, minibatch_index + 1, n_train_batches, this_validation_loss * 100.))                  
                if this_validation_loss < best_validation_loss:
                    if this_validation_loss < best_validation_loss * improvement_threshold:
                        patience = max(patience, iter * patience_increase)
                    best_validation_loss = this_validation_loss
                    test_losses = [test_model(i) for i in xrange(n_test_batches)]
                    test_score = np.mean(test_losses)
                    print ('epoch %i, minibatch %i/%i, test error of best model %f %%' % (epoch, minibatch_index + 1, n_train_batches, test_score * 100))
                if patience <= iter:
                    done_looping = True
                    break
        
    toc = time.clock()
    print (('Optimalization completes with the best validation loss of %f %%, with the best performance %f %%') % (best_validation_loss * 100., test_score * 100.))
    print 'The code runs for %d epochs, with %f epochs/sec' % (epoch, 1. * epoch / (toc - tic))
    
if __name__ == '__main__':
    sgd_optimization_mnist()
# Out:
# ...loading data
# ... building the model
# ... training the model
# epoch 1, minibatch 83/83, validation error 12.375000 %
# epoch 1, minibatch 83/83, test error of best model 12.458333 %
# epoch 2, minibatch 83/83, validation error 10.958333 %
# epoch 2, minibatch 83/83, test error of best model 11.010417 %
# epoch 3, minibatch 83/83, validation error 10.312500 %
# epoch 3, minibatch 83/83, test error of best model 10.312500 %
# epoch 4, minibatch 83/83, validation error 9.833333 %
# epoch 4, minibatch 83/83, test error of best model 9.875000 %
# epoch 5, minibatch 83/83, validation error 9.479167 %
# epoch 5, minibatch 83/83, test error of best model 9.562500 %
# epoch 6, minibatch 83/83, validation error 9.291667 %
# epoch 6, minibatch 83/83, test error of best model 9.322917 %
# epoch 7, minibatch 83/83, validation error 9.000000 %
# epoch 7, minibatch 83/83, test error of best model 9.187500 %
# epoch 8, minibatch 83/83, validation error 8.958333 %
# epoch 8, minibatch 83/83, test error of best model 8.989583 %
# epoch 9, minibatch 83/83, validation error 8.812500 %
# epoch 9, minibatch 83/83, test error of best model 8.937500 %
# epoch 10, minibatch 83/83, validation error 8.666667 %
# epoch 10, minibatch 83/83, test error of best model 8.750000 %
# epoch 11, minibatch 83/83, validation error 8.520833 %
# epoch 11, minibatch 83/83, test error of best model 8.666667 %
# epoch 12, minibatch 83/83, validation error 8.416667 %
# epoch 12, minibatch 83/83, test error of best model 8.583333 %
# epoch 13, minibatch 83/83, validation error 8.291667 %
# epoch 13, minibatch 83/83, test error of best model 8.489583 %
# epoch 14, minibatch 83/83, validation error 8.281250 %
# epoch 14, minibatch 83/83, test error of best model 8.427083 %
# epoch 15, minibatch 83/83, validation error 8.270833 %
# epoch 15, minibatch 83/83, test error of best model 8.354167 %
# epoch 16, minibatch 83/83, validation error 8.239583 %
# epoch 16, minibatch 83/83, test error of best model 8.302083 %
# epoch 17, minibatch 83/83, validation error 8.177083 %
# epoch 17, minibatch 83/83, test error of best model 8.250000 %
# epoch 18, minibatch 83/83, validation error 8.062500 %
# epoch 18, minibatch 83/83, test error of best model 8.229167 %
# epoch 19, minibatch 83/83, validation error 7.989583 %
# epoch 19, minibatch 83/83, test error of best model 8.260417 %
# epoch 20, minibatch 83/83, validation error 7.968750 %
# epoch 20, minibatch 83/83, test error of best model 8.260417 %
# epoch 21, minibatch 83/83, validation error 7.947917 %
# epoch 21, minibatch 83/83, test error of best model 8.208333 %
# epoch 22, minibatch 83/83, validation error 7.927083 %
# epoch 22, minibatch 83/83, test error of best model 8.187500 %
# epoch 23, minibatch 83/83, validation error 7.958333 %
# epoch 24, minibatch 83/83, validation error 7.947917 %
# epoch 25, minibatch 83/83, validation error 7.947917 %
# epoch 26, minibatch 83/83, validation error 7.927083 %
# epoch 26, minibatch 83/83, test error of best model 8.104167 %
# epoch 27, minibatch 83/83, validation error 7.885417 %
# epoch 27, minibatch 83/83, test error of best model 8.104167 %
# epoch 28, minibatch 83/83, validation error 7.843750 %
# epoch 28, minibatch 83/83, test error of best model 8.052083 %
# epoch 29, minibatch 83/83, validation error 7.822917 %
# epoch 29, minibatch 83/83, test error of best model 8.052083 %
# epoch 30, minibatch 83/83, validation error 7.843750 %
# epoch 31, minibatch 83/83, validation error 7.833333 %
# epoch 32, minibatch 83/83, validation error 7.812500 %
# epoch 32, minibatch 83/83, test error of best model 7.979167 %
# epoch 33, minibatch 83/83, validation error 7.739583 %
# epoch 33, minibatch 83/83, test error of best model 7.947917 %
# epoch 34, minibatch 83/83, validation error 7.729167 %
# epoch 34, minibatch 83/83, test error of best model 7.875000 %
# epoch 35, minibatch 83/83, validation error 7.718750 %
# epoch 35, minibatch 83/83, test error of best model 7.885417 %
# epoch 36, minibatch 83/83, validation error 7.697917 %
# epoch 36, minibatch 83/83, test error of best model 7.843750 %
# epoch 37, minibatch 83/83, validation error 7.635417 %
# epoch 37, minibatch 83/83, test error of best model 7.802083 %
# epoch 38, minibatch 83/83, validation error 7.625000 %
# epoch 38, minibatch 83/83, test error of best model 7.812500 %
# epoch 39, minibatch 83/83, validation error 7.625000 %
# epoch 40, minibatch 83/83, validation error 7.625000 %
# epoch 41, minibatch 83/83, validation error 7.625000 %
# epoch 42, minibatch 83/83, validation error 7.614583 %
# epoch 42, minibatch 83/83, test error of best model 7.770833 %
# epoch 43, minibatch 83/83, validation error 7.593750 %
# epoch 43, minibatch 83/83, test error of best model 7.750000 %
# epoch 44, minibatch 83/83, validation error 7.593750 %
# epoch 45, minibatch 83/83, validation error 7.583333 %
# epoch 45, minibatch 83/83, test error of best model 7.739583 %
# epoch 46, minibatch 83/83, validation error 7.552083 %
# epoch 46, minibatch 83/83, test error of best model 7.739583 %
# epoch 47, minibatch 83/83, validation error 7.562500 %
# epoch 48, minibatch 83/83, validation error 7.583333 %
# epoch 49, minibatch 83/83, validation error 7.572917 %
# epoch 50, minibatch 83/83, validation error 7.562500 %
# epoch 51, minibatch 83/83, validation error 7.552083 %
# epoch 52, minibatch 83/83, validation error 7.541667 %
# epoch 52, minibatch 83/83, test error of best model 7.656250 %
# epoch 53, minibatch 83/83, validation error 7.531250 %
# epoch 53, minibatch 83/83, test error of best model 7.656250 %
# epoch 54, minibatch 83/83, validation error 7.520833 %
# epoch 54, minibatch 83/83, test error of best model 7.635417 %
# epoch 55, minibatch 83/83, validation error 7.510417 %
# epoch 55, minibatch 83/83, test error of best model 7.635417 %
# epoch 56, minibatch 83/83, validation error 7.489583 %
# epoch 56, minibatch 83/83, test error of best model 7.635417 %
# epoch 57, minibatch 83/83, validation error 7.489583 %
# epoch 58, minibatch 83/83, validation error 7.458333 %
# epoch 58, minibatch 83/83, test error of best model 7.583333 %
# epoch 59, minibatch 83/83, validation error 7.468750 %
# epoch 60, minibatch 83/83, validation error 7.479167 %
# epoch 61, minibatch 83/83, validation error 7.510417 %
# epoch 62, minibatch 83/83, validation error 7.520833 %
# epoch 63, minibatch 83/83, validation error 7.510417 %
# epoch 64, minibatch 83/83, validation error 7.510417 %
# epoch 65, minibatch 83/83, validation error 7.510417 %
# epoch 66, minibatch 83/83, validation error 7.520833 %
# epoch 67, minibatch 83/83, validation error 7.500000 %
# epoch 68, minibatch 83/83, validation error 7.520833 %
# epoch 69, minibatch 83/83, validation error 7.500000 %
# epoch 70, minibatch 83/83, validation error 7.500000 %
# epoch 71, minibatch 83/83, validation error 7.510417 %
# epoch 72, minibatch 83/83, validation error 7.510417 %
# epoch 73, minibatch 83/83, validation error 7.489583 %
# epoch 74, minibatch 83/83, validation error 7.489583 %
# Optimalization completes with the best validation loss of 7.458333 %, with the best performance 7.583333 %
# The code runs for 74 epochs, with 2.090663 epochs/sec
